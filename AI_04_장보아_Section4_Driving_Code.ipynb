# %% [markdown]
# # 자율주행을 위한 자동차 객체 탐지

# %% [markdown]
# ## 데이터 셋 준비
# 자동차 블랙박스 영상을 활용하여 새로운 데이터 셋을 만들어 줍니다.
# 1분 짜리 영상을 10 프레임당 하나의 이미지로 추출합니다.

# %%
# %cd driving
# %pwd
# Out:
# /Users/boajang/Desktop/Project_S4/driving
# '/Users/boajang/Desktop/Project_S4/driving'

# %%
# 동영상을 프레임으로 변환하여 저장
import cv2
cap = cv2.VideoCapture('./driving.mp4')

# 비디오 프레임 크기, 전체 프레임수, FPS 등 출력
print('Frame width:', int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)))
print('Frame height:', int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print('Frame count:', int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print('FPS:', cap.get(cv2.CAP_PROP_FPS))

count = 0
while cap.isOpened():
    ret, frame = cap.read()
    # frame = cv2.resize(frame, (416,416))
    
    # 10 frame 당 하나씩 이미지 추출
    if int(cap.get(1))%10 == 0:
        cv2.imwrite('./export/images/image%d.jpg'%count, frame)

        count += 1
        
    if count == 179:
        break
        
print(count)
cap.release()
# Out:
# Frame width: 640
# Frame height: 360
# Frame count: 1799
# FPS: 29.970146468887023
# 179

# %% [markdown]
# ## 이미지 데이터 세트 준비
# 이미지 리스트 불러오기

# %%
# 이미지가 몇개인지 판단 및 이미지 리스트 불러오기
from glob import glob

# glob() 함수는 인자로 받은 패턴과 이름이 일치하는 모든 파일과 디렉토리의 리스트를 반환
img_list = glob('./export/images/*.jpg')

print(len(img_list))
# Out:
# 179

# %% [markdown]
# ## LabelImg
# LabelImg를 활용하여 이미지에 라벨을 추가합니다.

# %%
import os
LABELIMG_PATH = './labelimg'
# image labelling을 할 수 있는 github file을 불러온다.
if not os.path.exists(LABELIMG_PATH):
  # !mkdir {LABELIMG_PATH}
  # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into './labelimg'...
# remote: Enumerating objects: 1846, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 1846 (delta 38), reused 55 (delta 19), pack-reused 1759
# Receiving objects: 100% (1846/1846), 232.81 MiB | 8.21 MiB/s, done.
# Resolving deltas: 100% (1086/1086), done.

# %%
# !cd {LABELIMG_PATH} && make qt5py3
# Out:
# pyrcc5 -o libs/resources.py resources.qrc

# %%
# run label image python 
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# 2021-09-02 23:02:56.390 python[28172:1211290] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Image:/Users/boajang/Desktop/Project_S4/driving/export/images/image0.jpg -> Annotation:/Users/boajang/Desktop/Project_S4/driving/export/labels/image0.txt

# %% [markdown]
# ## 이미지 데이터를 train과 val 데이터 나누어줍니다.
# 학습 데이터와 테스트 데이터로 나누기

# %%
# split data to train and val 
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=42)

print(len(train_img_list),len(val_img_list))
# Out:
# 143 36

# %% [markdown]
# ## YoloV5를 활용하기 위한 .yaml 파일 준비

# %%
# %cat ./data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['car']

# %%
# write labels
# 나눈 데이터의 경로를 train.txt 와 val.txt 에 각각 나눠주기
with open('./train.txt','w') as f:
    f.write('\n'.join(train_img_list))
with open('./val.txt','w') as f:
    f.write('\n'.join(val_img_list))

# %%
# !pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp38-cp38-macosx_10_9_x86_64.whl (253 kB)
#      |████████████████████████████████| 253 kB 1.8 MB/s eta 0:00:01
# Installing collected packages: pyyaml
# Successfully installed pyyaml-5.4.1

# %%
# data.yaml 안의 경로 나누어진 데이터셋의 경로로 수정
import yaml
# yaml 파일 불러오기
with open('./data.yaml', 'r') as f:
    data = yaml.load(f)

print(data)

# 데이터 수정
data['train'] = './train.txt'
data['val'] = './val.txt'

# yaml 파일 저장
with open('./data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['car']}
# {'train': './train.txt', 'val': './val.txt', 'nc': 1, 'names': ['car']}
# /var/folders/66/xr9_bvqd73v1v5zl975wc5dc0000gn/T/ipykernel_22003/4237087232.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f)

# %% [markdown]
# ## YoloV5를 활용

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9310, done.
# remote: Total 9310 (delta 0), reused 0 (delta 0), pack-reused 9310
# Receiving objects: 100% (9310/9310), 9.63 MiB | 7.83 MiB/s, done.
# Resolving deltas: 100% (6477/6477), done.

# %%
# yolov5를 위한 패키지 설치
# %cd ./yolov5/
! pip install -r requirements.txt
# Out:
# /Users/boajang/Desktop/Project_S4/driving/yolov5
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.21.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.5.3.56)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (5.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.7.1)
# Requirement already satisfied: torch>=1.7.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (4.62.2)
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (2.6.0)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (0.11.2)
# Requirement already satisfied: pandas in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (1.3.2)
# Requirement already satisfied: thop in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (0.0.31.post2005241907)
# Requirement already satisfied: cycler>=0.10 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: typing-extensions in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 10)) (3.10.0.2)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.39.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (3.3.4)
# Requirement already satisfied: wheel>=0.26 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.37.0)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (3.17.3)
# Requirement already satisfied: absl-py>=0.4 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.13.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (52.0.0.post20210125)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: six in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 15)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 15)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.4.1->-r requirements.txt (line 15)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.4.1->-r requirements.txt (line 15)) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.4.1->-r requirements.txt (line 15)) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.4.1->-r requirements.txt (line 15)) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/boajang/opt/anaconda3/envs/project_s4/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 15)) (3.1.1)

# %% [markdown]
# ## 데이터를 YoloV5 파일과 함께

# %%
# copy data 
import shutil
# copy export file
src = './export'
dst = './yolov5/export'
shutil.copytree(src,dst)
# Out:
# './yolov5/export'

# %%
# copy train.txt
src = './train.txt'
dst = './yolov5/train.txt'
shutil.copy(src,dst)
# Out:
# './yolov5/train.txt'

# %%
# copy val.txt
src = './val.txt'
dst = './yolov5/val.txt'
shutil.copy(src,dst)
# Out:
# './yolov5/val.txt'

# %%
# copy data.yaml
src = './data.yaml'
dst = './yolov5/data.yaml'
shutil.copy(src,dst)
# Out:
# './yolov5/data.yaml'

# %% [markdown]
# ## Train Data
# 데이터 학습시키기
# ```
# --img : 이미지 크기
# --batch : 배치
# --epochs: 학습 횟수
# --data: yaml 파일
# --cfg: 모델 선택 -> yolov5s.yaml 선택
# --weight: pre-trained model(전이 학습)의 가중치 선택
# --name : 결과 저장할 폴더
# ```
# 학습에 걸리는 시간: 3.936 h

# %%
# run train 
# %cd ./yolov5/
# !python train.py --img 640 --batch 16 --epochs 50 --data ./data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name driving_yolov5s_results
# Out:
# [Errno 2] No such file or directory: './yolov5/'
# /Users/boajang/Desktop/Project_S4/driving/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=./data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=driving_yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-405-gfad57c2 torch 1.9.0 CPU
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPs
#
# Transferred 354/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 59 weight, 62 weight (no decay), 62 bias
# train: Scanning 'train.cache' images and labels... 143 found, 0 missing, 0 empty
# val: Scanning 'val.cache' images and labels... 36 found, 0 missing, 0 empty, 0 c
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.56, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/driving_yolov5s_results2
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/49        0G    0.1249    0.0503         0       189       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207     0.0422      0.106    0.00791    0.00126
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/49        0G    0.1219   0.05404         0       165       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207     0.0782      0.179     0.0209    0.00368
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/49        0G    0.1163    0.0588         0       182       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.117      0.295     0.0443    0.00884
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/49        0G    0.1066   0.06629         0       161       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.227       0.44      0.128     0.0241
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/49        0G   0.09914   0.07381         0       168       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.391      0.543      0.282     0.0702
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/49        0G   0.09123   0.08023         0       169       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.613      0.512      0.499      0.171
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/49        0G   0.08409   0.07601         0       157       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.719      0.522       0.56      0.233
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/49        0G   0.07789   0.08101         0       180       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.598      0.483      0.514      0.113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/49        0G   0.07433   0.07351         0       199       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.636      0.459      0.534     0.0996
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/49        0G   0.07088   0.06434         0       206       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.544      0.565      0.498      0.109
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/49        0G   0.06698   0.05795         0       146       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.703       0.56      0.649      0.229
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/49        0G   0.06293   0.05543         0       164       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.688      0.565      0.672      0.237
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/49        0G   0.06213   0.05345         0       160       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.708      0.599      0.675      0.243
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/49        0G   0.05801   0.04977         0       195       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.693        0.7       0.72      0.306
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/49        0G   0.05716   0.05069         0       166       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.726      0.728       0.76      0.304
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/49        0G   0.05539   0.04901         0       152       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.787      0.715      0.796      0.348
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/49        0G   0.05685   0.04639         0       135       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.664      0.715       0.72      0.278
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/49        0G   0.05402   0.04808         0       189       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.847      0.725      0.848      0.397
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/49        0G   0.05992   0.04612         0       151       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.365      0.686      0.374     0.0697
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/49        0G   0.07046   0.04891         0       190       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.447      0.655      0.513      0.134
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/49        0G   0.06428   0.04354         0       158       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.616      0.729      0.668       0.26
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/49        0G   0.06035   0.04551         0       158       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207       0.56      0.614      0.592      0.196
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/49        0G   0.06059   0.04339         0       188       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.691      0.604      0.664      0.276
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/49        0G   0.05878   0.04492         0       175       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.583      0.778      0.692      0.233
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/49        0G   0.05808    0.0446         0       130       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.802      0.685      0.791      0.329
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/49        0G   0.05657   0.04268         0       176       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.735      0.656      0.735      0.238
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/49        0G   0.05533   0.04336         0       177       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.674       0.67       0.71      0.253
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/49        0G   0.05856    0.0442         0       213       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.788      0.647      0.778      0.313
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/49        0G   0.05417   0.04337         0       207       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.778      0.696      0.807      0.339
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/49        0G   0.05605   0.04401         0       196       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.754      0.773      0.825      0.357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/49        0G   0.04981   0.04287         0       178       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.822      0.694      0.828      0.395
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/49        0G   0.04973    0.0424         0       181       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207       0.89      0.739      0.872      0.421
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/49        0G   0.04855   0.04533         0       210       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.821      0.691      0.836      0.372
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/49        0G   0.04896   0.03706         0       157       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.912      0.749      0.898      0.409
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/49        0G   0.04535   0.04117         0       146       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207       0.76      0.768      0.835      0.409
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/49        0G    0.0481   0.04328         0       153       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.747      0.742       0.82        0.4
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/49        0G   0.04594   0.04157         0       147       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.864      0.763      0.885      0.428
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/49        0G   0.04836   0.04152         0       142       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.797      0.894       0.91       0.47
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/49        0G   0.04582   0.04162         0       176       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.875      0.845      0.924      0.496
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/49        0G   0.04344   0.04164         0       159       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.812      0.836      0.899      0.424
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/49        0G   0.04269   0.04233         0       175       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.844      0.758      0.886      0.411
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/49        0G   0.04293   0.03933         0       154       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.946      0.758       0.91      0.505
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/49        0G   0.04098   0.04043         0       173       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.904      0.865      0.932       0.39
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/49        0G   0.04429   0.04277         0       185       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207       0.92      0.884      0.943      0.497
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/49        0G   0.04143   0.03796         0       135       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.919      0.879      0.945      0.516
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/49        0G   0.04008   0.04044         0       143       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.907      0.893      0.949      0.468
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/49        0G   0.03832   0.04006         0       172       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.763      0.855      0.893      0.446
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/49        0G   0.04136   0.04147         0       156       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.877      0.898      0.937      0.508
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/49        0G   0.03924   0.04204         0       158       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.881      0.898      0.944      0.548
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/49        0G   0.04146   0.04003         0       138       640: 100%|█|
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         36        207      0.862      0.884      0.937      0.507
#
# 50 epochs completed in 3.936 hours.
# Optimizer stripped from runs/train/driving_yolov5s_results2/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/driving_yolov5s_results2/weights/best.pt, 14.4MB
# Results saved to runs/train/driving_yolov5s_results2

# %% [markdown]
# ## 학습 시킨 weights와 하이퍼 파라미터 결과 확인하기

# %%
# %pwd
# Out:
# '/Users/boajang/Desktop/Project_S4/driving/yolov5'

# %%
# %cd yolov5
# Out:
# /Users/boajang/Desktop/Project_S4/driving/yolov5

# %%
# Tensorboard 
# %load_ext tensorboard
# %tensorboard --logdir ./runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 48695), started 0:04:19 ago. (Use '!kill 48695' to kill it.)
#       <iframe id="tensorboard-frame-1170e4f89b66acfa" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1170e4f89b66acfa");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# 테스트 데이터로 확인해보기 
# 50% 이상일 경우 표시
from IPython.display import Image
import os
 
val_img_path=val_img_list[0]
 
# !python detect.py --weights ./runs/train/driving_yolov5s_results/weights/best.pt --img 640 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['./runs/train/driving_yolov5s_results/weights/best.pt'], source=./export/images/image162.jpg, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-405-gfad57c2 torch 1.9.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /Users/boajang/Desktop/Project_S4/driving/yolov5/export/images/image162.jpg: 384x640 7 cars, Done. (0.363s)
# Results saved to runs/detect/exp2
# Done. (0.382s)

# %% [markdown]
# ## 영상으로 Detect 진행하기

# %%
# %cd ..
# Out:
# /Users/boajang/Desktop/Project_S4/driving

# %%
# copy data.yaml
src = './driving.mp4'
dst = './yolov5/driving.mp4'
shutil.copy(src,dst)
# Out:
# './yolov5/driving.mp4'

# %%
# %cd ./yolov5
# !python detect.py --weights ./runs/train/driving_yolov5s_results/weights/best.pt  --source ../driving.mp4
# Out:
# detect: weights=['./runs/train/driving_yolov5s_results/weights/best.pt'], source=../driving.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0
1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.296s)
# video 1/1 (1753/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.291s)
# video 1/1 (1754/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.294s)
# video 1/1 (1755/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.291s)
# video 1/1 (1756/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.291s)
# video 1/1 (1757/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.289s)
# video 1/1 (1758/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.295s)
# video 1/1 (1759/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.291s)
# video 1/1 (1760/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.289s)
# video 1/1 (1761/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.293s)
# video 1/1 (1762/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.293s)
# video 1/1 (1763/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.314s)
# video 1/1 (1764/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.295s)
# video 1/1 (1765/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.294s)
# video 1/1 (1766/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.296s)
# video 1/1 (1767/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.294s)
# video 1/1 (1768/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.295s)
# video 1/1 (1769/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.294s)
# video 1/1 (1770/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.291s)
# video 1/1 (1771/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.292s)
# video 1/1 (1772/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.293s)
# video 1/1 (1773/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.292s)
# video 1/1 (1774/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.293s)
# video 1/1 (1775/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.295s)
# video 1/1 (1776/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.297s)
# video 1/1 (1777/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.291s)
# video 1/1 (1778/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 4 cars, Done. (0.293s)
# video 1/1 (1779/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.290s)
# video 1/1 (1780/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.290s)
# video 1/1 (1781/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.292s)
# video 1/1 (1782/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.294s)
# video 1/1 (1783/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.294s)
# video 1/1 (1784/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.293s)
# video 1/1 (1785/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.297s)
# video 1/1 (1786/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.292s)
# video 1/1 (1787/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.297s)
# video 1/1 (1788/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.294s)
# video 1/1 (1789/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.293s)
# video 1/1 (1790/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.291s)
# video 1/1 (1791/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.292s)
# video 1/1 (1792/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.295s)
# video 1/1 (1793/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.296s)
# video 1/1 (1794/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.291s)
# video 1/1 (1795/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.292s)
# video 1/1 (1796/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 5 cars, Done. (0.293s)
# video 1/1 (1797/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.294s)
# video 1/1 (1798/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 6 cars, Done. (0.291s)
# video 1/1 (1799/1799) /Users/boajang/Desktop/Project_S4/driving/yolov5/../driving.mp4: 384x640 7 cars, Done. (0.294s)
# Results saved to runs/detect/exp3
# Done. (535.032s)

# %% [markdown]
# ## 다른 이미지로 Detect

# %%
# !python detect.py --weights ./runs/train/driving_yolov5s_results/weights/best.pt --img 640 --conf 0.5 --source ../1.jpg
# Out:
# detect: weights=['./runs/train/driving_yolov5s_results/weights/best.pt'], source=../1.jpg, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-405-gfad57c2 torch 1.9.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /Users/boajang/Desktop/Project_S4/driving/yolov5/../1.jpg: 448x640 18 cars, Done. (0.416s)
# Results saved to runs/detect/exp4
# Done. (0.451s)

# %%
# !python detect.py --weights ./runs/train/driving_yolov5s_results/weights/best.pt --img 640 --conf 0.5 --source ../2.jpg
# Out:
# detect: weights=['./runs/train/driving_yolov5s_results/weights/best.pt'], source=../2.jpg, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-405-gfad57c2 torch 1.9.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /Users/boajang/Desktop/Project_S4/driving/yolov5/../2.jpg: 640x640 6 cars, Done. (0.552s)
# Results saved to runs/detect/exp5
# Done. (0.560s)
